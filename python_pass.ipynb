# %% [markdown]
# <a href="https://colab.research.google.com/github/shahlaa1212/python-dart-pass/blob/main/python_pass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A Python program to demonstrate working of OrderedDict
from collections import OrderedDict
print("This is a Dict:\n")
d = {}
d['a'] = 1
d['b'] = 2
d['c'] = 3
d['d'] = 4
 
for key, value in d.items():
    print(key, value)
 
print("\nThis is an Ordered Dict:\n")
od = OrderedDict()
od['a'] = 1
od['b'] = 2
od['c'] = 3
od['d'] = 4
 
for key, value in od.items():
    print(key, value)
# Out:
# This is a Dict:
#
# a 1
# b 2
# c 3
# d 4
#
# This is an Ordered Dict:
#
# a 1
# b 2
# c 3
# d 4

# %%
students = {
    'Ahmed': 'Class 1',
    'Mustafa': 'Class 3',
    'Ali': 'Class 2',
    'Sara': 'Class 1',
    'Zainab': 'Class 1',
    'Zain': 'Class 2',
  }
dict(sorted(students.items()))
sortedByKey = {k: v for k, v in sorted(students.items())}
print(sortedByKey)
#sorted_d = sorted(students.items(), key = operator.itemgetter(1))
#print('Dictionary in ascending order by value : ',sorted_d)
# Out:
# {'Ahmed': 'Class 1', 'Ali': 'Class 2', 'Mustafa': 'Class 3', 'Sara': 'Class 1', 'Zain': 'Class 2', 'Zainab': 'Class 1'}

# %%
people = {
       3: "Jim", 
       2: "Jack",
       4: "Jane",
       1: "Jill", 
       1:"noor"
  }

# Sort by key
sortedByKey = {k: v for k, v in sorted(people.items())}
# dict(sorted(people.items()))
print(sortedByKey)
# Out:
# {1: 'noor', 2: 'Jack', 3: 'Jim', 4: 'Jane'}

# %%
def sort_dict_by_value(d, reverse = False):
  return dict(sorted(d.items(), key = lambda x: x[1], reverse = reverse))
print("Original dictionary elements:")
students = {
    'Ahmed': 'Class 1',
    'Mustafa': 'Class 3',
    'Ali': 'Class 2',
    'Sara': 'Class 1',
    'Zainab': 'Class 1',
    'Zain': 'Class 2',     
}
print(students)
print("\nSort (ascending) the said dictionary elements by value:")
print(sort_dict_by_value(students))
# Out:
# Original dictionary elements:
# {'Ahmed': 'Class 1', 'Mustafa': 'Class 3', 'Ali': 'Class 2', 'Sara': 'Class 1', 'Zainab': 'Class 1', 'Zain': 'Class 2'}
#
# Sort (ascending) the said dictionary elements by value:
# {'Ahmed': 'Class 1', 'Sara': 'Class 1', 'Zainab': 'Class 1', 'Ali': 'Class 2', 'Zain': 'Class 2', 'Mustafa': 'Class 3'}
